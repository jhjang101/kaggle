# %% [markdown]
# # 1. Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import *

# %%
# changing the max_columns value
pd.set_option("display.max_columns", None)

# set seaborn theme
sns.set_theme()
sns.set(font_scale=0.8)

# %% [markdown]
# # 2. Functions

# %%
def EDAplot(data=None, x=None, y=None):
    cor = round(df[y].corr(df[x]),3)
    
    fig = plt.figure(figsize=(8,2))
    fig.suptitle(f'{x} (corr: {cor})')
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    
    sns.histplot(data=data, x=x, kde=True, ax=ax1)
    sns.regplot(data=data, x=x, y=y, ax=ax2)
    
    return(plt.show())


def Model(model):
    
    # Build pipeline
    Input = [('scale',StandardScaler()), ('model',model)]
    pipe = Pipeline(Input)
    
    # Fit
    pipe.fit(x_train, y_train)
    
    # Metrics
    yhat_test = pipe.predict(x_test)
    score = r2_score(y_test, yhat_test)
    rmse = mean_squared_error(y_test, yhat_test, squared=False)
    df_fit.loc[len(df_fit)] = [f'{model}', score, rmse]
    
    # Plots
    fig, ax = plt.subplots(1, 3,  figsize=(12,2))
    fig.suptitle(f'{model}, R-squared: {round(score,3)}, RMSE:{round(rmse,3)}')
    # Distribution plot, Test vs Predicted
    sns.kdeplot(y_test, label='Actual Value', ax=ax[0])
    sns.kdeplot(yhat_test, label='Predicted Value', ax=ax[0])
    ax[0].legend(loc="upper right")
    # Scatter plot, Test vs Predicted
    sns.scatterplot(x=yhat_test, y=y_test, ax=ax[1])
    sns.lineplot(x=yhat_test, y=yhat_test, color='tab:orange', ax=ax[1])
    ax[1].set_xlabel('Predicted mpg')
    ax[1].set_ylabel('Actual mpg')
    # Residual plot
    sns.scatterplot(x=yhat_test, y=y_test-yhat_test, ax=ax[2])
    ax[2].axhline(y=0, color='tab:orange')
    ax[2].set_xlabel('Predicted mpg')
    ax[2].set_ylabel('Residuals')
    
    return(plt.show())

# %% [markdown]
# # 3. Data
# **Auto-mpg dataset** - Mileage per gallon performances of various cars.
#
# This dataset is a slightly modified version of the dataset provided in the StatLib library. In line with the use by Ross Quinlan (1993) in predicting the attribute "mpg", 8 of the original instances were removed because they had unknown values for the "mpg" attribute. This dataset and the original dataset is available in Kaggle https://www.kaggle.com/datasets/uciml/autompg-dataset

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin              car name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# Web searches to find some missing data;
#
# | Model          | horsepower |
# |:--------------:|:----------:|
# | ford pinto 71' | 75         |
# | ford maverick 74' | 82      |
# | renault lecar deluxe 80' | 50  |
# | ford mustang cobra 80' | 88 |
# | renault 18i 81' | 82 |
# | amc concord dl 82' | 82 |
#
# Add the hoesepower to the table

# %%
df.loc[32,'horsepower'] = 75
df.loc[126,'horsepower'] = 82
df.loc[330,'horsepower'] = 50
df.loc[336,'horsepower'] = 88
df.loc[354,'horsepower'] = 82
df.loc[374,'horsepower'] = 82
df['horsepower'] = df['horsepower'].astype(int)

# %%
df.describe().style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9dc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9dc2_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_e9dc2_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_e9dc2_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_e9dc2_level0_col3" class="col_heading level0 col3" >horsepower</th>
#       <th id="T_e9dc2_level0_col4" class="col_heading level0 col4" >weight</th>
#       <th id="T_e9dc2_level0_col5" class="col_heading level0 col5" >acceleration</th>
#       <th id="T_e9dc2_level0_col6" class="col_heading level0 col6" >model year</th>
#       <th id="T_e9dc2_level0_col7" class="col_heading level0 col7" >origin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9dc2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e9dc2_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_e9dc2_row0_col1" class="data row0 col1" >398</td>
#       <td id="T_e9dc2_row0_col2" class="data row0 col2" >398</td>
#       <td id="T_e9dc2_row0_col3" class="data row0 col3" >398</td>
#       <td id="T_e9dc2_row0_col4" class="data row0 col4" >398</td>
#       <td id="T_e9dc2_row0_col5" class="data row0 col5" >398</td>
#       <td id="T_e9dc2_row0_col6" class="data row0 col6" >398</td>
#       <td id="T_e9dc2_row0_col7" class="data row0 col7" >398</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_e9dc2_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_e9dc2_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_e9dc2_row1_col2" class="data row1 col2" >193</td>
#       <td id="T_e9dc2_row1_col3" class="data row1 col3" >104</td>
#       <td id="T_e9dc2_row1_col4" class="data row1 col4" >2970</td>
#       <td id="T_e9dc2_row1_col5" class="data row1 col5" >16</td>
#       <td id="T_e9dc2_row1_col6" class="data row1 col6" >76</td>
#       <td id="T_e9dc2_row1_col7" class="data row1 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_e9dc2_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_e9dc2_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_e9dc2_row2_col2" class="data row2 col2" >104</td>
#       <td id="T_e9dc2_row2_col3" class="data row2 col3" >38</td>
#       <td id="T_e9dc2_row2_col4" class="data row2 col4" >847</td>
#       <td id="T_e9dc2_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_e9dc2_row2_col6" class="data row2 col6" >4</td>
#       <td id="T_e9dc2_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_e9dc2_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_e9dc2_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_e9dc2_row3_col2" class="data row3 col2" >68</td>
#       <td id="T_e9dc2_row3_col3" class="data row3 col3" >46</td>
#       <td id="T_e9dc2_row3_col4" class="data row3 col4" >1613</td>
#       <td id="T_e9dc2_row3_col5" class="data row3 col5" >8</td>
#       <td id="T_e9dc2_row3_col6" class="data row3 col6" >70</td>
#       <td id="T_e9dc2_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_e9dc2_row4_col0" class="data row4 col0" >18</td>
#       <td id="T_e9dc2_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_e9dc2_row4_col2" class="data row4 col2" >104</td>
#       <td id="T_e9dc2_row4_col3" class="data row4 col3" >75</td>
#       <td id="T_e9dc2_row4_col4" class="data row4 col4" >2224</td>
#       <td id="T_e9dc2_row4_col5" class="data row4 col5" >14</td>
#       <td id="T_e9dc2_row4_col6" class="data row4 col6" >73</td>
#       <td id="T_e9dc2_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_e9dc2_row5_col0" class="data row5 col0" >23</td>
#       <td id="T_e9dc2_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_e9dc2_row5_col2" class="data row5 col2" >148</td>
#       <td id="T_e9dc2_row5_col3" class="data row5 col3" >92</td>
#       <td id="T_e9dc2_row5_col4" class="data row5 col4" >2804</td>
#       <td id="T_e9dc2_row5_col5" class="data row5 col5" >16</td>
#       <td id="T_e9dc2_row5_col6" class="data row5 col6" >76</td>
#       <td id="T_e9dc2_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_e9dc2_row6_col0" class="data row6 col0" >29</td>
#       <td id="T_e9dc2_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_e9dc2_row6_col2" class="data row6 col2" >262</td>
#       <td id="T_e9dc2_row6_col3" class="data row6 col3" >125</td>
#       <td id="T_e9dc2_row6_col4" class="data row6 col4" >3608</td>
#       <td id="T_e9dc2_row6_col5" class="data row6 col5" >17</td>
#       <td id="T_e9dc2_row6_col6" class="data row6 col6" >79</td>
#       <td id="T_e9dc2_row6_col7" class="data row6 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e9dc2_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_e9dc2_row7_col0" class="data row7 col0" >47</td>
#       <td id="T_e9dc2_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_e9dc2_row7_col2" class="data row7 col2" >455</td>
#       <td id="T_e9dc2_row7_col3" class="data row7 col3" >230</td>
#       <td id="T_e9dc2_row7_col4" class="data row7 col4" >5140</td>
#       <td id="T_e9dc2_row7_col5" class="data row7 col5" >25</td>
#       <td id="T_e9dc2_row7_col6" class="data row7 col6" >82</td>
#       <td id="T_e9dc2_row7_col7" class="data row7 col7" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 4. Exploratory Analysis

# %%
#correlation
plt.figure(figsize=(6,3))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))

sns.heatmap(df.corr(),annot=True, mask=mask, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
features = ['cylinders','displacement','horsepower','weight','acceleration','model year','origin']
for x in features:
    EDAplot(data=df, x=x, y='mpg')

# %% [markdown]
# ### Summary
# * Numerical variables - `cylinders`,`displacement`,`horsepower`,`weight`,`acceleration`,and `model year`
# * Categorical variables - `origin`

# %% [markdown]
# # 5. Model without categorical variable
# * Build `LinearRegression` model from numerical variables - `cylinders`,`displacement`,`horsepower`,`weight`,`acceleration`,and `model year`

# %% [markdown]
# ## 5.A. Feature Engineering

# %%
# X and Y variables selection
features = ['cylinders','displacement','horsepower', 'weight','acceleration', 'model year']
x = df[features]
y = df['mpg']

# Construct fit result table
df_fit = pd.DataFrame(columns=['Model','R2_test','RMSE','R2_CV'])

# Split train and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 5.B. LinearRegression
# * Cross-validation

# %% [markdown]
# ### 5.B.1. Model and Fit

# %%
# Build pipeline
model = LinearRegression()
Input = [('scale',StandardScaler()), ('model',model)]
pipe = Pipeline(Input)
    
# Fit
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %% [markdown]
# ### 5.B.2. Metrics and Cross-validation

# %%
# Metrics
yhat_test = pipe.predict(x_test)
r2_test = r2_score(y_test, yhat_test)
rmse = mean_squared_error(y_test, yhat_test, squared=False)

# cross_val_score
r2_CV = cross_val_score(pipe, x_train, y_train, cv=5).mean()

# Add to the result table
df_fit.loc[len(df_fit)] = [f'{model}', r2_test, rmse, r2_CV]

# Show the result table
df_fit
# Out:
#                 Model   R2_test     RMSE     R2_CV
# 0  LinearRegression()  0.824335  3.07325  0.791964

# %% [markdown]
# ### 5.B.3. Plots

# %%
# Generate plots figures
fig, ax = plt.subplots(1, 3,  figsize=(12,2))
fig.suptitle(f'{model}, R2_test: {round(r2_test,3)}, RMSE:{round(rmse,3)}')

# Distribution plot, Test vs Predicted
sns.kdeplot(y_test, label='Actual Value', ax=ax[0])
sns.kdeplot(yhat_test, label='Predicted Value', ax=ax[0])
ax[0].legend(loc="upper right")

# Scatter plot, Test vs Predicted
sns.scatterplot(x=yhat_test, y=y_test, ax=ax[1])
sns.lineplot(x=yhat_test, y=yhat_test, color='tab:orange', ax=ax[1])
ax[1].set_xlabel('Predicted mpg')
ax[1].set_ylabel('Actual mpg')

# Residual plot
sns.scatterplot(x=yhat_test, y=y_test-yhat_test, ax=ax[2])
ax[2].axhline(y=0, color='tab:orange')
ax[2].set_xlabel('Predicted mpg')
ax[2].set_ylabel('Residuals')
    
plt.show()

# %% [markdown]
# ## 5.C. Ridge
# * Use `GridSearchCV`

# %% [markdown]
# ### 5.B.1. Model

# %%
# GridSearchCV pipeline
estimator = Ridge()
pipe = Pipeline([('scale',StandardScaler()), ('model', estimator)])

# %% [markdown]
# ### 5.B.2. Hyperparameter Optimization - GridSearchCV

# %%
# Hyperparameters
alpha = [0.1, 1, 10, 100]

# GridSearchCV
parameters = [{'model__alpha':alpha}]
grid = GridSearchCV(pipe, parameters, scoring='r2', cv=5)
grid.fit(x_train, y_train)
print(f'best alpha: {alpha[grid.best_index_]}')
print(f'score: {grid.best_score_}')
# Out:
# best alpha: 1
# score: 0.7928298359066712

# %% [markdown]
# ### 5.B.3. Metrics

# %%
# Metrics
model = grid.best_estimator_[1]
yhat_test = grid.predict(x_test)
r2_test = r2_score(y_test, yhat_test)
rmse = mean_squared_error(y_test, yhat_test, squared=False)

# cross_val_score
r2_CV = grid.best_score_

# Add to the result table
df_fit.loc[len(df_fit)] = [f'{model}', r2_test, rmse, r2_CV]

# Show the result table
df_fit
# Out:
#                 Model   R2_test      RMSE     R2_CV
# 0  LinearRegression()  0.824335  3.073250  0.791964
# 1      Ridge(alpha=1)  0.824664  3.070376  0.792830

# %% [markdown]
# ### 5.B.3. Plots

# %%
# Generate plots figures
fig, ax = plt.subplots(1, 3,  figsize=(12,2))
fig.suptitle(f'{model}, R2_test: {round(r2_test,3)}, RMSE:{round(rmse,3)}')

# Distribution plot, Test vs Predicted
sns.kdeplot(y_test, label='Actual Value', ax=ax[0])
sns.kdeplot(yhat_test, label='Predicted Value', ax=ax[0])
ax[0].legend(loc="upper right")

# Scatter plot, Test vs Predicted
sns.scatterplot(x=yhat_test, y=y_test, ax=ax[1])
sns.lineplot(x=yhat_test, y=yhat_test, color='tab:orange', ax=ax[1])
ax[1].set_xlabel('Predicted mpg')
ax[1].set_ylabel('Actual mpg')

# Residual plot
sns.scatterplot(x=yhat_test, y=y_test-yhat_test, ax=ax[2])
ax[2].axhline(y=0, color='tab:orange')
ax[2].set_xlabel('Predicted mpg')
ax[2].set_ylabel('Residuals')
    
plt.show()

# %% [markdown]
# # 6. Compare Linear Model
# Build linear model with six numerical variables.

# %%
features = ['cylinders','displacement','horsepower', 'weight','acceleration', 'model year']
x = df[features]
y = df['mpg']

# %% [markdown]
# ### Split train and test set

# %%
#  spilt
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Model and Fit

# %%
df_fit = pd.DataFrame(columns=['Model','R-squared','RMSE'])
models = [LinearRegression(), Ridge(1), Lasso(1)]

for model in models:
    Model(model)
    
df_fit
# Out:
#                 Model  R-squared      RMSE
# 0  LinearRegression()   0.824335  3.073250
# 1      Ridge(alpha=1)   0.824664  3.070376
# 2      Lasso(alpha=1)   0.832739  2.998836

# %%
grid.get_params().keys()
# Out:
# dict_keys(['cv', 'error_score', 'estimator__memory', 'estimator__steps', 'estimator__verbose', 'estimator__scale', 'estimator__model', 'estimator__scale__copy', 'estimator__scale__with_mean', 'estimator__scale__with_std', 'estimator__model__alpha', 'estimator__model__copy_X', 'estimator__model__fit_intercept', 'estimator__model__max_iter', 'estimator__model__normalize', 'estimator__model__positive', 'estimator__model__random_state', 'estimator__model__solver', 'estimator__model__tol', 'estimator', 'n_jobs', 'param_grid', 'pre_dispatch', 'refit', 'return_train_score', 'scoring', 'verbose'])

# %%
model = Ridge()
Input = [('scale',StandardScaler()), ('model', model)]
pipe = Pipeline(Input)
parameters = [{'model__alpha':[0,0.1,1,10,20,50,60,70,80, 90,100,110,120,130,140,150,160,170,180, 1000]}]
grid = GridSearchCV(pipe, parameters, scoring='r2')
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('model', Ridge())]),
#              param_grid=[{'model__alpha': [0, 0.1, 1, 10, 20, 50, 60, 70, 80,
#                                            90, 100, 110, 120, 130, 140, 150,
#                                            160, 170, 180, 1000]}],
#              scoring='r2')

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', Ridge(alpha=1))])

# %%
grid.best_score_
# Out:
# 0.7928298359066712

# %%
grid.scorer_
# Out:
# make_scorer(r2_score)

# %%
yhat_test = grid.predict(x_test)
score = r2_score(y_test, yhat_test)
rmse = mean_squared_error(y_test, yhat_test, squared=False)

# %%
score
# Out:
# 0.8246636755109868

# %%
results = pd.DataFrame(columns=['alpha', 'R2_train', 'R2_test'])

for alpha in [0,0.1,1,10,20,50,60,70,80, 90,100,110,120,130,140,150,160,170,180, 1000]:
    model = Ridge(alpha)
    Input = [('scale',StandardScaler()), ('model', model)]
    pipe = Pipeline(Input)
    pipe.fit(x_train, y_train)
    # train R2
    R2_train = pipe.score(x_train, y_train)
    # test R2
    yhat_test = pipe.predict(x_test)
    R2_test = r2_score(y_test, yhat_test)
    results.loc[len(results)] = [alpha, R2_train, R2_test]

# %%
results
# Out:
#      alpha  R2_train   R2_test
# 0      0.0  0.803881  0.824335
# 1      0.1  0.803881  0.824372
# 2      1.0  0.803823  0.824664
# 3     10.0  0.800996  0.825727
# 4     20.0  0.797065  0.825754
# 5     50.0  0.787391  0.825107
# 6     60.0  0.784673  0.824779
# 7     70.0  0.782096  0.824383
# 8     80.0  0.779619  0.823917
# 9     90.0  0.777216  0.823382
# 10   100.0  0.774868  0.822778
# 11   110.0  0.772562  0.822109
# 12   120.0  0.770290  0.821378
# 13   130.0  0.768043  0.820587
# 14   140.0  0.765817  0.819742
# 15   150.0  0.763608  0.818844
# 16   160.0  0.761414  0.817897
# 17   170.0  0.759232  0.816904
# 18   180.0  0.757061  0.815868
# 19  1000.0  0.599070  0.683710

# %%
results = pd.DataFrame(columns=['alpha', 'R2_train', 'R2_test'])

for alpha in [0,0.1,1,10,20,50,60,70,80, 90,100,110,120,130,140,150,160,170,180, 1000]:
    model = Ridge(alpha)
    Input = [('scale',StandardScaler()), ('model', model)]
    pipe = Pipeline(Input)
    pipe.fit(x_train, y_train)
    # train R2
    R2_train = pipe.score(x_train, y_train)
    # test R2
    yhat_test = pipe.predict(x_test)
    R2_test = r2_score(y_test, yhat_test)
    results.loc[len(results)] = [alpha, R2_train, R2_test]

# %%
cv_results = cross_validate(Ridge(1), x_train, y_train, cv=5)
np.mean(cv_results['test_score'])
# Out:
# 0.7919849740786044

# %%
alpha = [0.1, 1, 10, 100]

# GridSearchCV
estimator = Ridge()
pipe = Pipeline([('scale',StandardScaler()), ('model', estimator)])
parameters = [{'model__alpha':alpha}]
grid = GridSearchCV(pipe, parameters, scoring='r2', cv=5)
grid.fit(x_train, y_train)
print(f'best alpha: {alpha[grid.best_index_]}')
print(f'score: {grid.best_score_}')
# Out:
# best alpha: 1
# score: 0.7928298359066712

# %%
# cross_validate
for n in alpha:
    estimator = Ridge(n)
    pipe = Pipeline([('scale',StandardScaler()), ('model', estimator)])
    cv = cross_validate(pipe, x_train, y_train, cv=5)
    print(np.mean(cv['test_score']))
# Out:
# 0.792070783047686
# 0.7928298359066712
# 0.7925228759526153
# 0.7642608655422137

# %%
# cross_val_score
for n in alpha:
    estimator = Ridge(n)
    pipe = Pipeline([('scale',StandardScaler()), ('model', estimator)])
    cvs = cross_val_score(pipe, x_train, y_train, cv=5)
    print(np.mean(cvs))
# Out:
# 0.792070783047686
# 0.7928298359066712
# 0.7925228759526153
# 0.7642608655422137

# %%
# Ridge

results = pd.DataFrame(columns=['alpha', 'R2_train', 'R2_test'])
for n in alpha:
    estimator = Ridge(n)
    pipe = Pipeline([('scale',StandardScaler()), ('model', estimator)])
    pipe.fit(x_train, y_train)
    # train R2
    R2_train = pipe.score(x_train, y_train)
    # test R2
    yhat_test = pipe.predict(x_test)
    R2_test = r2_score(y_test, yhat_test)
    results.loc[len(results)] = [n, R2_train, R2_test]
results
# Out:
#    alpha  R2_train   R2_test
# 0    0.1  0.803881  0.824372
# 1    1.0  0.803823  0.824664
# 2   10.0  0.800996  0.825727
# 3  100.0  0.774868  0.822778
