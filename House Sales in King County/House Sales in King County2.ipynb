# %% [markdown]
# # House Sales in King County, USA
#
# ## Data set
#
# This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015. It's a great dataset for evaluating simple regression models. The original dataset is obtained from Kaggle: https://www.kaggle.com/datasets/harlfoxem/housesalesprediction
#
# In this demo, I will use various regression methods to model the house sales price and evaluate the model with test set.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LinearRegression

# %%
# changing the max_columns value
pd.set_option("display.max_columns", None)

# set seaborn theme
sb.set_theme()

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# **Data Impression and Variables**
#
# The dataset has total 21 columns and price is the analysis target.

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# ### Column statistics

# %%
df.describe().style.format(precision=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ee4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ee4c_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_8ee4c_level0_col1" class="col_heading level0 col1" >price</th>
#       <th id="T_8ee4c_level0_col2" class="col_heading level0 col2" >bedrooms</th>
#       <th id="T_8ee4c_level0_col3" class="col_heading level0 col3" >bathrooms</th>
#       <th id="T_8ee4c_level0_col4" class="col_heading level0 col4" >sqft_living</th>
#       <th id="T_8ee4c_level0_col5" class="col_heading level0 col5" >sqft_lot</th>
#       <th id="T_8ee4c_level0_col6" class="col_heading level0 col6" >floors</th>
#       <th id="T_8ee4c_level0_col7" class="col_heading level0 col7" >waterfront</th>
#       <th id="T_8ee4c_level0_col8" class="col_heading level0 col8" >view</th>
#       <th id="T_8ee4c_level0_col9" class="col_heading level0 col9" >condition</th>
#       <th id="T_8ee4c_level0_col10" class="col_heading level0 col10" >grade</th>
#       <th id="T_8ee4c_level0_col11" class="col_heading level0 col11" >sqft_above</th>
#       <th id="T_8ee4c_level0_col12" class="col_heading level0 col12" >sqft_basement</th>
#       <th id="T_8ee4c_level0_col13" class="col_heading level0 col13" >yr_built</th>
#       <th id="T_8ee4c_level0_col14" class="col_heading level0 col14" >yr_renovated</th>
#       <th id="T_8ee4c_level0_col15" class="col_heading level0 col15" >zipcode</th>
#       <th id="T_8ee4c_level0_col16" class="col_heading level0 col16" >lat</th>
#       <th id="T_8ee4c_level0_col17" class="col_heading level0 col17" >long</th>
#       <th id="T_8ee4c_level0_col18" class="col_heading level0 col18" >sqft_living15</th>
#       <th id="T_8ee4c_level0_col19" class="col_heading level0 col19" >sqft_lot15</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ee4c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8ee4c_row0_col0" class="data row0 col0" >21613.000</td>
#       <td id="T_8ee4c_row0_col1" class="data row0 col1" >21613.000</td>
#       <td id="T_8ee4c_row0_col2" class="data row0 col2" >21613.000</td>
#       <td id="T_8ee4c_row0_col3" class="data row0 col3" >21613.000</td>
#       <td id="T_8ee4c_row0_col4" class="data row0 col4" >21613.000</td>
#       <td id="T_8ee4c_row0_col5" class="data row0 col5" >21613.000</td>
#       <td id="T_8ee4c_row0_col6" class="data row0 col6" >21613.000</td>
#       <td id="T_8ee4c_row0_col7" class="data row0 col7" >21613.000</td>
#       <td id="T_8ee4c_row0_col8" class="data row0 col8" >21613.000</td>
#       <td id="T_8ee4c_row0_col9" class="data row0 col9" >21613.000</td>
#       <td id="T_8ee4c_row0_col10" class="data row0 col10" >21613.000</td>
#       <td id="T_8ee4c_row0_col11" class="data row0 col11" >21613.000</td>
#       <td id="T_8ee4c_row0_col12" class="data row0 col12" >21613.000</td>
#       <td id="T_8ee4c_row0_col13" class="data row0 col13" >21613.000</td>
#       <td id="T_8ee4c_row0_col14" class="data row0 col14" >21613.000</td>
#       <td id="T_8ee4c_row0_col15" class="data row0 col15" >21613.000</td>
#       <td id="T_8ee4c_row0_col16" class="data row0 col16" >21613.000</td>
#       <td id="T_8ee4c_row0_col17" class="data row0 col17" >21613.000</td>
#       <td id="T_8ee4c_row0_col18" class="data row0 col18" >21613.000</td>
#       <td id="T_8ee4c_row0_col19" class="data row0 col19" >21613.000</td>
#     </tr>
#     <tr>
#       <th id="T_8ee4c_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8ee4c_row1_col0" class="data row1 col0" >4580301520.865</td>
#       <td id="T_8ee4c_row1_col1" class="data row1 col1" >540088.142</td>
#       <td id="T_8ee4c_row1_col2" class="data row1 col2" >3.371</td>
#       <td id="T_8ee4c_row1_col3" class="data row1 col3" >2.115</td>
#       <td id="T_8ee4c_row1_col4" class="data row1 col4" >2079.900</td>
#       <td id="T_8ee4c_row1_col5" class="data row1 col5" >15106.968</td>
#       <td id="T_8ee4c_row1_col6" class="data row1 col6" >1.494</td>
#       <td id="T_8ee4c_row1_col7" class="data row1 col7" >0.008</td>
#       <td id="T_8ee4c_row1_col8" class="data row1 col8" >0.234</td>
#       <td id="T_8ee4c_row1_col9" class="data row1 col9" >3.409</td>
#       <td id="T_8ee4c_row1_col10" class="data row1 col10" >7.657</td>
#       <td id="T_8ee4c_row1_col11" class="data row1 col11" >1788.391</td>
#       <td id="T_8ee4c_row1_col12" class="data row1 col12" >291.509</td>
#       <td id="T_8ee4c_row1_col13" class="data row1 col13" >1971.005</td>
#       <td id="T_8ee4c_row1_col14" class="data row1 col14" >84.402</td>
#       <td id="T_8ee4c_row1_col15" class="data row1 col15" >98077.940</td>
#       <td id="T_8ee4c_row1_col16" class="data row1 col16" >47.560</td>
#       <td id="T_8ee4c_row1_col17" class="data row1 col17" >-122.214</td>
#       <td id="T_8ee4c_row1_col18" class="data row1 col18" >1986.552</td>
#       <td id="T_8ee4c_row1_col19" class="data row1 col19" >12768.456</td>
#     </tr>
#     <tr>
#       <th id="T_8ee4c_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8ee4c_row2_col0" class="data row2 col0" >2876565571.312</td>
#       <td id="T_8ee4c_row2_col1" class="data row2 col1" >367127.196</td>
#       <td id="T_8ee4c_row2_col2" class="data row2 col2" >0.930</td>
#       <td id="T_8ee4c_row2_col3" class="data row2 col3" >0.770</td>
#       <td id="T_8ee4c_row2_col4" class="data row2 col4" >918.441</td>
#       <td id="T_8ee4c_row2_col5" class="data row2 col5" >41420.512</td>
#       <td id="T_8ee4c_row2_col6" class="data row2 col6" >0.540</td>
#       <td id="T_8ee4c_row2_col7" class="data row2 col7" >0.087</td>
#       <td id="T_8ee4c_row2_col8" class="data row2 col8" >0.766</td>
#       <td id="T_8ee4c_row2_col9" class="data row2 col9" >0.651</td>
#       <td id="T_8ee4c_row2_col10" class="data row2 col10" >1.175</td>
#       <td id="T_8ee4c_row2_col11" class="data row2 col11" >828.091</td>
#       <td id="T_8ee4c_row2_col12" class="data row2 col12" >442.575</td>
#       <td id="T_8ee4c_row2_col13" class="data row2 col13" >29.373</td>
#       <td id="T_8ee4c_row2_col14" class="data row2 col14" >401.679</td>
#       <td id="T_8ee4c_row2_col15" class="data row2 col15" >53.505</td>
#       <td id="T_8ee4c_row2_col16" class="data row2 col16" >0.139</td>
#       <td id="T_8ee4c_row2_col17" class="data row2 col17" >0.141</td>
#       <td id="T_8ee4c_row2_col18" class="data row2 col18" >685.391</td>
#       <td id="T_8ee4c_row2_col19" class="data row2 col19" >27304.180</td>
#     </tr>
#     <tr>
#       <th id="T_8ee4c_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_8ee4c_row3_col0" class="data row3 col0" >1000102.000</td>
#       <td id="T_8ee4c_row3_col1" class="data row3 col1" >75000.000</td>
#       <td id="T_8ee4c_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_8ee4c_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_8ee4c_row3_col4" class="data row3 col4" >290.000</td>
#       <td id="T_8ee4c_row3_col5" class="data row3 col5" >520.000</td>
#       <td id="T_8ee4c_row3_col6" class="data row3 col6" >1.000</td>
#       <td id="T_8ee4c_row3_col7" class="data row3 col7" >0.000</td>
#       <td id="T_8ee4c_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_8ee4c_row3_col9" class="data row3 col9" >1.000</td>
#       <td id="T_8ee4c_row3_col10" class="data row3 col10" >1.000</td>
#       <td id="T_8ee4c_row3_col11" class="data row3 col11" >290.000</td>
#       <td id="T_8ee4c_row3_col12" class="data row3 col12" >0.000</td>
#       <td id="T_8ee4c_row3_col13" class="data row3 col13" >1900.000</td>
#       <td id="T_8ee4c_row3_col14" class="data row3 col14" >0.000</td>
#       <td id="T_8ee4c_row3_col15" class="data row3 col15" >98001.000</td>
#       <td id="T_8ee4c_row3_col16" class="data row3 col16" >47.156</td>
#       <td id="T_8ee4c_row3_col17" class="data row3 col17" >-122.519</td>
#       <td id="T_8ee4c_row3_col18" class="data row3 col18" >399.000</td>
#       <td id="T_8ee4c_row3_col19" class="data row3 col19" >651.000</td>
#     </tr>
#     <tr>
#       <th id="T_8ee4c_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id

# %% [markdown]
# * There are total 21613 data points.
# * House price range from 75K to 7,700K.

# %% [markdown]
# ### Distribution of house price
#
# The house prices are expected to have alot of outliers.

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 4))

sb.boxplot(y = df['price'], ax = ax[0])
sb.kdeplot(x = df['price'], ax = ax[1])

plt.show()

# %% [markdown]
# ### Remove outliers
#
# Calculate IQR, upper, and lower limit.\
# Check fraction of the outliers and remove them.

# %%
# calculate quantiles and IQRs

q1 = df['price'].quantile(0.25)
q3 = df['price'].quantile(0.75)
iqr = q3 - q1
low_limit = q1 - 1.5 * iqr
up_limit = q3 + 1.5 * iqr

print('Q1 =', q1)
print('Q3 =', q3)
print('IQR =', iqr)
print('Lower Limit =', low_limit)
print('Upper Limit =', up_limit)
# Out:
# Q1 = 321950.0
# Q3 = 645000.0
# IQR = 323050.0
# Lower Limit = -162625.0
# Upper Limit = 1129575.0

# %%
# fraction of house price higher than upper limit
high_price = df['price']<up_limit
high_price.value_counts()[0]/(high_price.value_counts()[0]+high_price.value_counts()[1])
# Out:
# 0.053023643177717114

# %%
# drop price highr than upper limit
df = df[high_price]
df.shape
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.046700e+04  2.046700e+04  20467.000000  20467.000000  20467.000000
# mean   4.603223e+09  4.769846e+05      3.329750      2.051632   1975.558167
# std    2.877364e+09  2.083713e+05      0.912885      0.711906    774.833460
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.131701e+09  3.150000e+05      3.000000      1.500000   1400.000000
# 50%    3.905082e+09  4.375000e+05      3.000000      2.000000   1860.000000
# 75%    7.338101e+09  6.000000e+05      4.000000      2.500000   2431.000000
# max    9.900000e+09  1.127500e+06     33.000000      7.500000   7480.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.046700e+04  20467.000000  20467.000000  20467.000000  20467.000000
# mean   1.461041e+04      1.476035      0.002980      0.172668      3.406361
# std    4.010956e+04      0.537033      0.054513      0.640950      0.647228
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.000000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.500000e+03      1.000000      0.000000      0.000000      3.000000
# 75%    1.031900e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  20467.000000  20467.000000   20467.000000  20467.000000  20467.000000
# mean       7.530561   1708.330972     267.227195   1970.811013     74.681145
# std        1.039192    727.296461     409.031661     29.160540    378.761647
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1170.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1520.000000       0.000000   1974.000000      0.000000
# 75%        8.000000   2100.000000     510.000000   1996.000000      0.000000
# max       12.000000   5710.000000    2720.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  20467.000000  20467.000000  20467.000000   20467.000000   20467.000000
# mean   98078.555773     47.556888   -122.213265    1922.255191   12447.084526
# std       53.336953      0.141038      0.142412     614.932010   26538.592250
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.460400   -122.330000    1470.000000    5046.000000
# 50%    98065.000000     47.567000   -122.232000    1800.000000    7542.000000
# 75%    98118.000000     47.679800   -122.123000    2280.000000    9883.500000
# max    98199.000000     47.777600   -121.315000    5380.000000  871200.000000

# %% [markdown]
# ### Bedrooms
# Integer range from 0 to 33

# %%
# define a function to plot feature vs price
def FeaturePlot(feature = None, histwidth = None , scale = 'log', bin=20):
    """
    Plot histoplot, boxplot(y = price) and scatterplot(y = price)
    :param feature: column name to plot. string
    :param histwidth: binwidth parameter in the histplot. float
    :param scale: yscale in the histplot. {'linear', 'log', 'symlog', 'logit'...}
    :param bin: if feature is numerical values bin them for box plot. integer
    :return: histoplot, boxplot, and scatterplot
    """
    
    fig = plt.figure(figsize=(25,3))
    ax1 = fig.add_subplot(1,5,1)
    ax2 = fig.add_subplot(1,5,2)
    ax3 = fig.add_subplot(1,5,3)
    ax4 = fig.add_subplot(1,5,4)
    ax5 = fig.add_subplot(1,5,5)

    # ax1: histplot
    sb.histplot(data=df, x=feature, binwidth=histwidth, ax=ax1)
    ax1.set_yscale(scale)

    # ax2: boxplot    
    if len(df[feature].unique())>bin:    # if feature is numerical values bin them for box plot
        min = df[feature].min()
        max = df[feature].max()
        base = 1 if round((max - min)/15)==0 else round((max - min)/15)
        df_bin = round(df[feature]/base)*base
        sb.boxplot(y=df['price'], x=df_bin, ax=ax2)
    else:
        sb.boxplot(data=df, y='price', x=feature, ax=ax2)
    ax2.tick_params(axis='x', rotation=45)
    
    # ax3: scatterplot  
    # sb.scatterplot(data=df, y='price', x=feature, ax=ax3)
    sb.regplot(data=df, y='price', x=feature,line_kws={'color':'black'}, scatter_kws={'alpha':0.2}, ax=ax3)
    cor = df['price'].corr(df[feature])
    ax3.set_title('Corr:'+str(cor))
    
    sb.residplot(data=df, y='price', x=feature, scatter_kws={'alpha':0.2}, ax=ax4)
    
    

    reg = LinearRegression()
    reg.fit(df[[feature]], df['price'])
    resid = df['price']-reg.predict(df[[feature]])
    sb.histplot(resid, kde=True, ax=ax5)
    ax5.set_xlim(-2000000, 2000000)
    
    
    return(plt.show(fig))

# %%
FeaturePlot(feature='bedrooms', histwidth=1, scale='log', bin=20)

# %% [markdown]
# #### Remove outlier
#
# Remove the house with 33 bedrooms

# %%
df = df[df['bedrooms'] != 33]

# %% [markdown]
# ### Bathrooms
# 26 unique values ranges from 0 to 7.5

# %%
FeaturePlot(feature='bathrooms', histwidth=None, scale='log', bin=20)

# %% [markdown]
# ### SQFT Living and SQFT Lot Space
#
# There is newly measured sqft_living15 and sqft_lot15. Will not be used.

# %% [markdown]
# ### Floors
#
# Ranges from 1 to 3.5.

# %%
FeaturePlot(feature='floors', histwidth=0.5, scale='log', bin=20)

# %% [markdown]
# ### Waterfront
# Categorical value. Majority is 0. Low correlation. Will not use for model.

# %%
FeaturePlot(feature='waterfront', histwidth=None, scale='log', bin=20)

# %% [markdown]
# ### View
#
# Categorical value. View column is number of views of the house listed. Supposedly, view should not be a reliable independent variable. but it shows 0.24 correlation and some degree of linearity.

# %%
FeaturePlot(feature='view', histwidth=1, scale='log', bin=20)

# %% [markdown]
# ## Condition
#
# Catrgorical value of the house condition. Weak correlation.

# %%
FeaturePlot(feature='condition', histwidth=1, scale='log', bin=20)

# %% [markdown]
# ### Grade
#
# Grade of the house. Shows good correlation.

# %%
FeaturePlot(feature='grade', histwidth=1, scale='log', bin=20)

# %% [markdown]
# ### Sqft_above
#
# Shows good correlation.

# %%
FeaturePlot(feature='sqft_above', histwidth=500, scale='log', bin=20)

# %% [markdown]
# ### sqft_basement
#
# Weak correlartion. many of them has 0 value. distribution of the residuals is not normal. Will not use for prediction.

# %%
FeaturePlot(feature='sqft_basement', histwidth=None, scale='log', bin=20)

# %% [markdown]
# ### yr_built

# %%
FeaturePlot(feature='yr_built', histwidth=None, scale='log', bin=20)

# %%
FeaturePlot(feature='zipcode', histwidth=None, scale='log', bin=20)

# %%
yr_built	yr_renovated	zipcode
